# %%
import databroker as db

# %%
db.DataBroker[-1]
# Out:
# {'descriptors': [{'data_keys': {'delta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Del}Mtr.RBV'},
#     'epu1_gap': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:1-Ax:Gap}Pos-I'},
#     'epu1_phase': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:1-Ax:Phase}Pos-I'},
#     'epu2_gap': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:2-Ax:Gap}Pos-I'},
#     'epu2_phase': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:2-Ax:Phase}Pos-I'},
#     'eta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Diag:1-Ax:Eta}Mtr.RBV'},
#     'fccd_acquire_period': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquirePeriod_RBV'},
#     'fccd_acquire_time': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquireTime_RBV'},
#     'fccd_image_lightfield': {'dtype': 'array',
#      'external': 'FILESTORE:',
#      'shape': [60, 960, 960],
#      'source': 'PV:XF:23ID1-ES{FCCD}'},
#     'fccd_stats_total1': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats1:Total_RBV'},
#     'fccd_stats_total2': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats2:Total_RBV'},
#     'fccd_stats_total3': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats3:Total_RBV'},
#     'fccd_stats_total4': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats4:Total_RBV'},
#     'fccd_stats_total5': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats5:Total_RBV'},
#     'gamma': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Gam}Mtr.RBV'},
#     'm1a_pit': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Pit}Mtr_MON'},
#     'm1a_rol': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Rol}Mtr_MON'},
#     'm1a_x': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:X}Mtr_MON'},
#     'm1a_y': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Y}Mtr_MON'},
#     'm1a_yaw': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Yaw}Mtr_MON'},
#     'm1a_z': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Z}Mtr_MON'},
#     'm3a_bdr': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mir:3-Ax:Bdr}Mtr.RBV'},
#     'npbx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmX}Mtr.RBV'},
#     'npby': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmY}Mtr.RBV'},
#     'npbz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmZ}Mtr.RBV'},
#     'nptx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopX}Mtr.RBV'},
#     'npty': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopY}Mtr.RBV'},
#     'nptz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopZ}Mtr.RBV'},
#     'pgm_energy': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mono}Enrgy-I'},
#     'pgm_energy_sp': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mono}Enrgy-SP'},
#     'ring_curr': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-SR{}I-I'},
#     'say': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Y}Mtr.RBV'},
#     'saz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Z}Mtr.RBV'},
#     'sclr_chan1': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S1'},
#     'sclr_chan2': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S2'},
#     'sclr_chan3': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S3'},
#     'sclr_chan4': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S4'},
#     'sclr_chan5': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S5'},
#     'sclr_chan6': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S6'},
#     'sclr_chan7': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S7'},
#     'sclr_chan8': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S8'},
#     'sclr_time': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.T'},
#     'slt1_xc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XCtr}Mtr.RBV'},
#     'slt1_xg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XGap}Mtr.RBV'},
#     'slt1_yc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YCtr}Mtr.RBV'},
#     'slt1_yg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YGap}Mtr.RBV'},
#     'slt2_xc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XCtr}Mtr.RBV'},
#     'slt2_xg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XGap}Mtr.RBV'},
#     'slt2_yc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YCtr}Mtr.RBV'},
#     'slt2_yg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YGap}Mtr.RBV'},
#     'slt3_x': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:3-Ax:X}Mtr.RBV'},
#     'slt3_y': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:3-Ax:Y}Mtr.RBV'},
#     'sx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#     'sy': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#     'sz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:SZ}Pos-RB'},
#     'temp_a': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#     'temp_b': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'},
#     'theta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Th}Mtr.RBV'}},
#    'run_start': '95f25412-a093-46bd-ba8b-d23e8e46a5e5',
#    'time': 1447946092.0155044,
#    'uid': '74e158e0-96fd-4137-b360-ba84b43977f1'},
#   {'data_keys': {'topoff_inj': {'dtype': 'number',
#      'shape': [],
#      'source': 'XF:23ID1-SR{TO-Inj}'}},
#    'run_start': '95f25412-a093-46bd-ba8b-d23e8e46a5e5',
#    'time': 1447946092.053964,
#    'uid': 'f24420c1-3244-48e4-b721-dc7a7bb24104'},
#   {'data_keys': {'fccd_flyer5': {'dtype': 'number',
#      'shape': [],
#      'source': 'XF:23ID1-ES{FCCD}Stats5:'}},
#    'run_start': '95f25412-a093-46bd-ba8b-d23e8e46a5e5',
#    'time': 1447946092.0642638,
#    'uid': '698e810c-df3a-4582-a9b9-5088d8bba0fc'},
#   {'data_keys': {'diag6_flyer1': {'dtype': 'number',
#      'shape': [],
#      'source': 'XF:23ID1-BI{Diag:6-Cam:1}Stats1:'}},
#    'run_start': '95f25412-a093-46bd-ba8b-d23e8e46a5e5',
#    'time': 1447946092.0969272,
#    'uid': '26eb16d5-fafe-41ed-9c76-a5936ea7514b'}],
#  'start': {'beamline_id': 'CSX',
#   'config': {},
#   'group': '',
#   'owner': 'xf23id1',
#   'project': 'SAF 300177, Prop. 300369',
#   'sample': {'sample': 'xpcs25_138'},
#   'scan_id': 56428,
#   'scan_type': 'Count',
#   'time': 1447945964.532538,
#   'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#  'stop': {'exit_status': 'success',
#   'reason': '',
#   'run_start': '95f25412-a093-46bd-ba8b-d23e8e46a5e5',
#   'time': 1447946097.7352781,
#   'uid': 'c512ff0d-fdde-440a-824b-7c40befd9c33'}}

# %%
h = db.DataBroker['95f25']

# %%
h.descriptors[0]
# Out:
# {'data_keys': {'delta': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:Del}Mtr.RBV'},
#   'epu1_gap': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID-ID{EPU:1-Ax:Gap}Pos-I'},
#   'epu1_phase': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID-ID{EPU:1-Ax:Phase}Pos-I'},
#   'epu2_gap': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID-ID{EPU:2-Ax:Gap}Pos-I'},
#   'epu2_phase': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID-ID{EPU:2-Ax:Phase}Pos-I'},
#   'eta': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Diag:1-Ax:Eta}Mtr.RBV'},
#   'fccd_acquire_period': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquirePeriod_RBV'},
#   'fccd_acquire_time': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquireTime_RBV'},
#   'fccd_image_lightfield': {'dtype': 'array',
#    'external': 'FILESTORE:',
#    'shape': [60, 960, 960],
#    'source': 'PV:XF:23ID1-ES{FCCD}'},
#   'fccd_stats_total1': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}Stats1:Total_RBV'},
#   'fccd_stats_total2': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}Stats2:Total_RBV'},
#   'fccd_stats_total3': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}Stats3:Total_RBV'},
#   'fccd_stats_total4': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}Stats4:Total_RBV'},
#   'fccd_stats_total5': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{FCCD}Stats5:Total_RBV'},
#   'gamma': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:Gam}Mtr.RBV'},
#   'm1a_pit': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Pit}Mtr_MON'},
#   'm1a_rol': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Rol}Mtr_MON'},
#   'm1a_x': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:X}Mtr_MON'},
#   'm1a_y': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Y}Mtr_MON'},
#   'm1a_yaw': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Yaw}Mtr_MON'},
#   'm1a_z': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Z}Mtr_MON'},
#   'm3a_bdr': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Mir:3-Ax:Bdr}Mtr.RBV'},
#   'npbx': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmX}Mtr.RBV'},
#   'npby': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmY}Mtr.RBV'},
#   'npbz': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmZ}Mtr.RBV'},
#   'nptx': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopX}Mtr.RBV'},
#   'npty': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopY}Mtr.RBV'},
#   'nptz': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopZ}Mtr.RBV'},
#   'pgm_energy': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Mono}Enrgy-I'},
#   'pgm_energy_sp': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Mono}Enrgy-SP'},
#   'ring_curr': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID-SR{}I-I'},
#   'say': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:Y}Mtr.RBV'},
#   'saz': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:Z}Mtr.RBV'},
#   'sclr_chan1': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S1'},
#   'sclr_chan2': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S2'},
#   'sclr_chan3': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S3'},
#   'sclr_chan4': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S4'},
#   'sclr_chan5': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S5'},
#   'sclr_chan6': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S6'},
#   'sclr_chan7': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S7'},
#   'sclr_chan8': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.S8'},
#   'sclr_time': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Sclr:1}.T'},
#   'slt1_xc': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XCtr}Mtr.RBV'},
#   'slt1_xg': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XGap}Mtr.RBV'},
#   'slt1_yc': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YCtr}Mtr.RBV'},
#   'slt1_yg': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YGap}Mtr.RBV'},
#   'slt2_xc': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XCtr}Mtr.RBV'},
#   'slt2_xg': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XGap}Mtr.RBV'},
#   'slt2_yc': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YCtr}Mtr.RBV'},
#   'slt2_yg': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YGap}Mtr.RBV'},
#   'slt3_x': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:3-Ax:X}Mtr.RBV'},
#   'slt3_y': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-OP{Slt:3-Ax:Y}Mtr.RBV'},
#   'sx': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#   'sy': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#   'sz': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:SZ}Pos-RB'},
#   'temp_a': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#   'temp_b': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'},
#   'theta': {'dtype': 'number',
#    'shape': [],
#    'source': 'PV:XF:23ID1-ES{Dif-Ax:Th}Mtr.RBV'}},
#  'run_start': '95f25412-a093-46bd-ba8b-d23e8e46a5e5',
#  'time': 1447946092.0155044,
#  'uid': '74e158e0-96fd-4137-b360-ba84b43977f1'}

# %%
evs = db.get_events(h)

# %%
evs
# Out:
# <generator object get_events at 0x7ff05ac16708>

# %%
evs = list(evs)

# %%
len(evs)
# Out:
# 6199

# %%
[e for e in evs if len(e['data'])> 1]
# Out:
# [{'data': {'delta': 8.399985000000001,
#    'epu1_gap': 200.00035520000003,
#    'epu1_phase': -2.72e-05,
#    'epu2_gap': 21.099982400000002,
#    'epu2_phase': 16.200032,
#    'eta': -0.021707593999998664,
#    'fccd_acquire_period': 1.0,
#    'fccd_acquire_time': 2.0,
#    'fccd_image_lightfield': 'acd83032-cd7a-42af-89ff-9791eec5cb9f',
#    'fccd_stats_total1': 303514691567.0,
#    'fccd_stats_total2': 2617911236553.0,
#    'fccd_stats_total3': 75576674637.0,
#    'fccd_stats_total4': 44015745987.0,
#    'fccd_stats_total5': 49060014293.0,
#    'gamma': 9.199999426,
#    'm1a_pit': 0.8099458347999999,
#    'm1a_rol': 5.599855186,
#    'm1a_x': 8.726153958e-05,
#    'm1a_y': 0.8002668327,
#    'm1a_yaw': -0.00015943479623,
#    'm1a_z': 27.50004335,
#    'm3a_bdr': -0.6202500000000001,
#    'npbx': -0.081135,
#    'npby': -16.999155,
#    'npbz': -7.4988850000000005,
#    'nptx': -6.68003,
#    'npty': -3.5591849999999976,
#    'nptz': -1.0,
#    'pgm_energy': 690.0314365,
#    'pgm_energy_sp': 690.0,
#    'ring_curr': 149.7585535678416,
#    'say': -22.3764975,
#    'saz': -4.2597075,
#    'sclr_chan1': 4.0,
#    'sclr_chan2': 430604.0,
#    'sclr_chan3': 295998.0,
#    'sclr_chan4': 1588708.0,
#    'sclr_chan5': 423933.0,
#    'sclr_chan6': 0.0,
#    'sclr_chan7': 0.0,
#    'sclr_chan8': 0.0,
#    'sclr_time': 8e-08,
#    'slt1_xc': 0.2047000000000001,
#    'slt1_xg': 7.0002999999999975,
#    'slt1_yc': -0.3004,
#    'slt1_yg': 7.000299999999999,
#    'slt2_xc': 1.0,
#    'slt2_xg': 10.0,
#    'slt2_yc': -5.0001,
#    'slt2_yg': -1.7763568394002505e-15,
#    'slt3_x': 2.64982,
#    'slt3_y': -0.24976,
#    'sx': 1.299999535,
#    'sy': -0.39999941231915037,
#    'sz': 0.7800015287660446,
#    'temp_a': 199.996,
#    'temp_b': 201.303,
#    'theta': 4.000005000000002},
#   'descriptor': {'data_keys': {'delta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Del}Mtr.RBV'},
#     'epu1_gap': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:1-Ax:Gap}Pos-I'},
#     'epu1_phase': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:1-Ax:Phase}Pos-I'},
#     'epu2_gap': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:2-Ax:Gap}Pos-I'},
#     'epu2_phase': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:2-Ax:Phase}Pos-I'},
#     'eta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Diag:1-Ax:Eta}Mtr.RBV'},
#     'fccd_acquire_period': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquirePeriod_RBV'},
#     'fccd_acquire_time': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquireTime_RBV'},
#     'fccd_image_lightfield': {'dtype': 'array',
#      'external': 'FILESTORE:',
#      'shape': [60, 960, 960],
#      'source': 'PV:XF:23ID1-ES{FCCD}'},
#     'fccd_stats_total1': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats1:Total_RBV'},
#     'fccd_stats_total2': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats2:Total_RBV'},
#     'fccd_stats_total3': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats3:Total_RBV'},
#     'fccd_stats_total4': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats4:Total_RBV'},
#     'fccd_stats_total5': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats5:Total_RBV'},
#     'gamma': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Gam}Mtr.RBV'},
#     'm1a_pit': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Pit}Mtr_MON'},
#     'm1a_rol': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Rol}Mtr_MON'},
#     'm1a_x': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:X}Mtr_MON'},
#     'm1a_y': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Y}Mtr_MON'},
#     'm1a_yaw': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Yaw}Mtr_MON'},
#     'm1a_z': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Z}Mtr_MON'},
#     'm3a_bdr': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mir:3-Ax:Bdr}Mtr.RBV'},
#     'npbx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmX}Mtr.RBV'},
#     'npby': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmY}Mtr.RBV'},
#     'npbz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmZ}Mtr.RBV'},
#     'nptx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopX}Mtr.RBV'},
#     'npty': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopY}Mtr.RBV'},
#     'nptz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopZ}Mtr.RBV'},
#     'pgm_energy': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mono}Enrgy-I'},
#     'pgm_energy_sp': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mono}Enrgy-SP'},
#     'ring_curr': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-SR{}I-I'},
#     'say': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Y}Mtr.RBV'},
#     'saz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Z}Mtr.RBV'},
#     'sclr_chan1': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S1'},
#     'sclr_chan2': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S2'},
#     'sclr_chan3': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S3'},
#     'sclr_chan4': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S4'},
#     'sclr_chan5': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S5'},
#     'sclr_chan6': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S6'},
#     'sclr_chan7': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S7'},
#     'sclr_chan8': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S8'},
#     'sclr_time': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.T'},
#     'slt1_xc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XCtr}Mtr.RBV'},
#     'slt1_xg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XGap}Mtr.RBV'},
#     'slt1_yc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YCtr}Mtr.RBV'},
#     'slt1_yg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YGap}Mtr.RBV'},
#     'slt2_xc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XCtr}Mtr.RBV'},
#     'slt2_xg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XGap}Mtr.RBV'},
#     'slt2_yc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YCtr}Mtr.RBV'},
#     'slt2_yg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YGap}Mtr.RBV'},
#     'slt3_x': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:3-Ax:X}Mtr.RBV'},
#     'slt3_y': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:3-Ax:Y}Mtr.RBV'},
#     'sx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#     'sy': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#     'sz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:SZ}Pos-RB'},
#     'temp_a': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#     'temp_b': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'},
#     'theta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Th}Mtr.RBV'}},
#    'run_start': {'beamline_id': 'CSX',
#     'config': {},
#     'group': '',
#     'owner': 'xf23id1',
#     'project': 'SAF 300177, Prop. 300369',
#     'sample': {'sample': 'xpcs25_138'},
#     'scan_id': 56428,
#     'scan_type': 'Count',
#     'time': 1447945964.532538,
#     'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#    'time': 1447946092.0155044,
#    'uid': '74e158e0-96fd-4137-b360-ba84b43977f1'},
#   'seq_num': 1,
#   'time': 1447946092.039139,
#   'timestamps': {'delta': 1447922242.109872,
#    'epu1_gap': 1447946091.794043,
#    'epu1_phase': 1447946091.832232,
#    'epu2_gap': 1447946091.925366,
#    'epu2_phase': 1447946090.981466,
#    'eta': 1447686379.47819,
#    'fccd_acquire_period': 1447089296.827231,
#    'fccd_acquire_time': 1447945400.333751,
#    'fccd_image_lightfield': 1447946091.904507,
#    'fccd_stats_total1': 1447946091.903744,
#    'fccd_stats_total2': 1447946091.911404,
#    'fccd_stats_total3': 1447946091.911682,
#    'fccd_stats_total4': 1447946091.911858,
#    'fccd_stats_total5': 1447946091.901194,
#    'gamma': 1447907391.561242,
#    'm1a_pit': 1447919179.662958,
#    'm1a_rol': 1447919179.663057,
#    'm1a_x': 1447919179.663202,
#    'm1a_y': 1447919179.663176,
#    'm1a_yaw': 1447919179.66307,
#    'm1a_z': 1447919179.663187,
#    'm3a_bdr': 1447924222.174169,
#    'npbx': 1447946091.957448,
#    'npby': 1447946089.917354,
#    'npbz': 1447946088.898603,
#    'nptx': 1447946091.948101,
#    'npty': 1447946091.951224,
#    'nptz': 1447946078.651855,
#    'pgm_energy': 1447946091.934182,
#    'pgm_energy_sp': 1447940750.261772,
#    'ring_curr': 1447946091.095016,
#    'say': 1447895037.227402,
#    'saz': 1447895041.824885,
#    'sclr_chan1': 1447945965.120869,
#    'sclr_chan2': 1447945965.120869,
#    'sclr_chan3': 1447945965.120869,
#    'sclr_chan4': 1447945965.120869,
#    'sclr_chan5': 1447945965.120869,
#    'sclr_chan6': 1447867645.13862,
#    'sclr_chan7': 1447867645.13862,
#    'sclr_chan8': 1447867645.13862,
#    'sclr_time': 1447945965.120869,
#    'slt1_xc': 1447946084.6963,
#    'slt1_xg': 1447946088.712624,
#    'slt1_yc': 1447931362.529507,
#    'slt1_yg': 1447946090.430477,
#    'slt2_xc': 1447867645.062325,
#    'slt2_xg': 1447867645.062304,
#    'slt2_yc': 1447867645.821821,
#    'slt2_yg': 1447867645.8218,
#    'slt3_x': 1447946077.553153,
#    'slt3_y': 1447946069.229347,
#    'sx': 1447898364.880222,
#    'sy': 1447895041.824973,
#    'sz': 1447895041.824982,
#    'temp_a': 1447946091.04889,
#    'temp_b': 1447946091.118655,
#    'theta': 1447907318.324657},
#   'uid': 'f9abb12e-02ed-4eef-9e37-357048fc6184'}]

# %%
from itertools import chain
# BEGIN LPy
try:
    from itertools import zip_longest
except ImportError:
    from itertools import izip_longest as zip_longest
# END LPy
import uuid
import time as ttime
import operator as op
from functools import reduce


def pivot_timeseries(events, pivot_keys, static_keys=None):
    """Pivot sequence of events with sequences as data to single sequence
    For example a sequence of 5 events with 100 frames of 2D data per datum
    will turn into a sequence of 500 events which each have a single frame.
    Any keys not in ``pivot_keys`` or ``static_keys`` will be dropped.
    This will return new event documents with a new Descriptor which is
    not in the database.
    Parameters
    ----------
    events : sequence
        A sequence of events all with the same Descriptor
    pivot_keys : sequence
        A list of keys from the events to pivot out
    static_keys : sequence, optional
        A list of keys from the original events to propagate
        to the new events
    Yields
    ------
    event : doc
        The pivoted document
    """
    if static_keys is None:
        static_keys = []
    if set(pivot_keys) & set(static_keys):
        raise RuntimeError("Pivot and static_keys overlap")

    events = iter(events)
    ev0 = next(events)
    orig_desc = ev0['descriptor']
    new_desc = {'uid': str(uuid.uuid4()),
                'data_keys': dict(),
                'run_start': orig_desc['run_start'],
                'time': ttime.time()}
    new_desc['data_keys']['fr_no'] = {'shape': (),
                                      'dtype': 'number',
                                      'source': 'pivot'}
    for key in static_keys:
        new_desc['data_keys'][key] = orig_desc['data_keys'][key]
    for key in pivot_keys:
        orig_data_key = orig_desc['data_keys'][key]
        if orig_data_key['dtype'] != 'array':
            raise RuntimeError("trying to pivot on non-array data")

    pv_lens = [orig_desc['data_keys'][k]['shape'][0] for k in pivot_keys]
    if not all(pv_lens[0] == pl for pl in pv_lens):
        raise RuntimeError("not all pivot columns are the same length")

    seq_no = 0
    for ev in chain((ev0, ), events):
        inner_desc = dict(new_desc)
        inner_desc['data_keys'] = dict(inner_desc['data_keys'])
        for key in pivot_keys:
            orig_data_key = orig_desc['data_keys'][key]
            shape = orig_data_key['shape'][1:]
            dtype = 'array' if shape else 'number'
            inner_desc['data_keys'][key] = {'shape': shape,
                                            'dtype': dtype,
                                            'source': ev['uid']}

        data = ev['data']
        ts = ev['timestamps']
        time = ev['time']
        static_data = {k: data[k] for k in static_keys}
        static_ts = {k: ts[k] for k in chain(static_keys, pivot_keys)}

        pivot_data = zip(*[data[k] for k in pivot_keys])

        for fr_no, _data in enumerate(pivot_data):
            new_ev = {'uid': str(uuid.uuid4()),
                      'time': time,
                      'descriptor': inner_desc,
                      'seq_no': seq_no,
                      }
            inner_data = dict(static_data)
            inner_data.update({k: v for k, v in zip(pivot_keys, _data)})
            inner_data['fr_no'] = fr_no
            inner_ts = dict(static_ts)
            inner_ts['fr_no'] = ttime.time()
            new_ev['data'] = inner_data
            new_ev['timestamps'] = inner_ts
            yield new_ev
            seq_no += 1


def zip_events(*evs, **kwargs):
    """Zip together a collection of event streams
    All events in a single stream must have the same
    descriptor.
    All event streams must be the same length
    All event streams must have same run_start (for now)
    Parameters
    ----------
    *evs
        sequences that yield events
    lazy : bool, optional
        If False, listify event streams first for validation
        defaults to True
    """
    # BEGIN LPy
    # Once we drop LPy support the signature can be changed back to
    # def zip_events(*evs, lazy=True)
    # the code below is to work around limitations of the LPy syntax
    lazy = kwargs.pop('lazy', True)
    if len(kwargs):
        raise TypeError("Passed unknown key word arguments")
    # END LPy

    if not lazy:
        # need to listify
        evs = [list(ev) for ev in evs]
        lens = [len(ev) for ev in evs]
        # TODO check single descriptor invariant
        if not all(l == lens[0] for l in lens):
            raise RuntimeError("All event streams must be same len")

    # set up iterators and spy on the first event
    evs = [iter(ev) for ev in evs]
    first_events = [next(ev) for ev in evs]
    evs = [chain((ev0, ), ev) for ev0, ev in zip(first_events, evs)]
    # make new descriptor
    descs = [ev['descriptor'] for ev in first_events]
    if not all(d['run_start'] == descs[0]['run_start'] for d in descs):
        raise RuntimeError("Not all descriptors have same runstart")
    sum_keys = set(chain(*(d['data_keys'] for d in descs)))
    if len(sum_keys) != reduce(op.add, [len(d['data_keys']) for d in descs]):
        raise RuntimeError("event descriptors have overlapping keys")
    zip_desc = {'uid': str(uuid.uuid4()),
                'data_keys': dict(),
                'run_start': descs[0]['run_start'],
                'time': ttime.time()}
    for d in descs:
        zip_desc['data_keys'].update(d['data_keys'])

    for seq_no, events in enumerate(zip_longest(*evs)):
        if any(ev is None for ev in events):
            raise RuntimeError("not all streams same length")
        for ev, desc in zip(events, descs):
            if ev['descriptor']['uid'] != desc['uid']:
                raise RuntimeError("one of event streams changes descriptors")
        new_ev = {'uid': str(uuid.uuid4()),
                  'time': ttime.time(),
                  'descriptor': zip_desc,
                  'seq_no': seq_no,
                  'data': dict(),
                  'timestamps': dict()}
        for ev in events:
            new_ev['data'].update(ev['data'])
            new_ev['timestamps'].update(ev['timestamps'])

        yield new_ev


def reset_time(evs, field, source='timestamps'):
    """Reset the time field on the event.
    Promote a specific timestamp to be the time of the whole
    event.
    Parameters
    ----------
    evs : iterable
        Iterable of events to work on
    field : str
        The field to use for the value
    source : {'timestamps', 'data'}, optional
        Where to look for that field
    Yields
    ------
    events
    """
    for ev in evs:
        ev = dict(ev)
        ev['time'] = ev[source][field]
        yield ev

# %%
from metadatastore.commands import get_events_generator

# %%
events1 = list(get_events_generator(h.descriptors[0]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-e7a30dd6c226> in <module>()
# ----> 1 events1 = list(get_events_generator(h.descriptors[0], fill=True))
#
# /opt/conda_envs/analysis/lib/python3.4/site-packages/metadatastore/commands.py in inner(*args, **kwargs)
#     118         port = int(conf.connection_config['port'])
#     119         db_connect(database=database, host=host, port=port)
# --> 120         return func(*args, **kwargs)
#     121     return inner
#     122
#
# TypeError: get_events_generator() got an unexpected keyword argument 'fill'

# %%
from databroker.databroker import fill_event

# %%
list(map(fill_event, events1))
# Out:
# [None]

# %%
events1
# Out:
# [{'data': {'delta': 8.399985000000001,
#    'epu1_gap': 200.00035520000003,
#    'epu1_phase': -2.72e-05,
#    'epu2_gap': 21.099982400000002,
#    'epu2_phase': 16.200032,
#    'eta': -0.021707593999998664,
#    'fccd_acquire_period': 1.0,
#    'fccd_acquire_time': 2.0,
#    'fccd_image_lightfield': array([[[53358, 53359, 53357, ..., 53264, 53264, 53239],
#            [53357, 53358, 53355, ..., 53264, 53262, 53237],
#            [53356, 53359, 53356, ..., 53265, 53265, 53239],
#            ...,
#            [53178, 53182, 53184, ..., 53207, 53207, 53208],
#            [53177, 53183, 53183, ..., 53208, 53211, 53208],
#            [53179, 53183, 53185, ..., 53210, 53209, 53210]],
#
#           [[53356, 53357, 53353, ..., 53264, 53264, 53239],
#            [53358, 53357, 53357, ..., 53266, 53266, 53241],
#            [53356, 53358, 53356, ..., 53264, 53264, 53240],
#            ...,
#            [53180, 53184, 53186, ..., 53211, 53211, 53209],
#            [53181, 53182, 53185, ..., 53212, 53212, 53209],
#            [53179, 53183, 53184, ..., 53209, 53210, 53206]],
#
#           [[53358, 53359, 53359, ..., 53265, 53265, 53238],
#            [53356, 53360, 53357, ..., 53263, 53264, 53238],
#            [53355, 53356, 53353, ..., 53265, 53265, 53237],
#            ...,
#            [53180, 53185, 53186, ..., 53206, 53203, 53205],
#            [53177, 53186, 53183, ..., 53204, 53208, 53206],
#            [53178, 53183, 53185, ..., 53208, 53208, 53205]],
#
#           ...,
#           [[53359, 53359, 53357, ..., 53263, 53263, 53239],
#            [53358, 53358, 53359, ..., 53262, 53260, 53234],
#            [53358, 53359, 53359, ..., 53262, 53264, 53239],
#            ...,
#            [53180, 53185, 53184, ..., 53211, 53211, 53210],
#            [53175, 53183, 53183, ..., 53209, 53211, 53209],
#            [53181, 53187, 53184, ..., 53207, 53208, 53209]],
#
#           [[53360, 53358, 53359, ..., 53260, 53263, 53237],
#            [53358, 53359, 53359, ..., 53265, 53263, 53238],
#            [53358, 53358, 53355, ..., 53263, 53263, 53235],
#            ...,
#            [53175, 53181, 53182, ..., 53207, 53207, 53204],
#            [53178, 53184, 53184, ..., 53209, 53212, 53210],
#            [53178, 53180, 53181, ..., 53208, 53210, 53209]],
#
#           [[53358, 53356, 53357, ..., 53261, 53262, 53235],
#            [53357, 53358, 53359, ..., 53262, 53262, 53235],
#            [53356, 53357, 53354, ..., 53262, 53262, 53237],
#            ...,
#            [53179, 53181, 53184, ..., 53206, 53208, 53207],
#            [53178, 53183, 53182, ..., 53209, 53212, 53212],
#            [53174, 53181, 53181, ..., 53209, 53209, 53211]]], dtype=uint16),
#    'fccd_stats_total1': 303514691567.0,
#    'fccd_stats_total2': 2617911236553.0,
#    'fccd_stats_total3': 75576674637.0,
#    'fccd_stats_total4': 44015745987.0,
#    'fccd_stats_total5': 49060014293.0,
#    'gamma': 9.199999426,
#    'm1a_pit': 0.8099458347999999,
#    'm1a_rol': 5.599855186,
#    'm1a_x': 8.726153958e-05,
#    'm1a_y': 0.8002668327,
#    'm1a_yaw': -0.00015943479623,
#    'm1a_z': 27.50004335,
#    'm3a_bdr': -0.6202500000000001,
#    'npbx': -0.081135,
#    'npby': -16.999155,
#    'npbz': -7.4988850000000005,
#    'nptx': -6.68003,
#    'npty': -3.5591849999999976,
#    'nptz': -1.0,
#    'pgm_energy': 690.0314365,
#    'pgm_energy_sp': 690.0,
#    'ring_curr': 149.7585535678416,
#    'say': -22.3764975,
#    'saz': -4.2597075,
#    'sclr_chan1': 4.0,
#    'sclr_chan2': 430604.0,
#    'sclr_chan3': 295998.0,
#    'sclr_chan4': 1588708.0,
#    'sclr_chan5': 423933.0,
#    'sclr_chan6': 0.0,
#    'sclr_chan7': 0.0,
#    'sclr_chan8': 0.0,
#    'sclr_time': 8e-08,
#    'slt1_xc': 0.2047000000000001,
#    'slt1_xg': 7.0002999999999975,
#    'slt1_yc': -0.3004,
#    'slt1_yg': 7.000299999999999,
#    'slt2_xc': 1.0,
#    'slt2_xg': 10.0,
#    'slt2_yc': -5.0001,
#    'slt2_yg': -1.7763568394002505e-15,
#    'slt3_x': 2.64982,
#    'slt3_y': -0.24976,
#    'sx': 1.299999535,
#    'sy': -0.39999941231915037,
#    'sz': 0.7800015287660446,
#    'temp_a': 199.996,
#    'temp_b': 201.303,
#    'theta': 4.000005000000002},
#   'descriptor': {'data_keys': {'delta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Del}Mtr.RBV'},
#     'epu1_gap': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:1-Ax:Gap}Pos-I'},
#     'epu1_phase': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:1-Ax:Phase}Pos-I'},
#     'epu2_gap': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:2-Ax:Gap}Pos-I'},
#     'epu2_phase': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-ID{EPU:2-Ax:Phase}Pos-I'},
#     'eta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Diag:1-Ax:Eta}Mtr.RBV'},
#     'fccd_acquire_period': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquirePeriod_RBV'},
#     'fccd_acquire_time': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}cam1:AcquireTime_RBV'},
#     'fccd_image_lightfield': {'dtype': 'array',
#      'external': 'FILESTORE:',
#      'shape': [60, 960, 960],
#      'source': 'PV:XF:23ID1-ES{FCCD}'},
#     'fccd_stats_total1': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats1:Total_RBV'},
#     'fccd_stats_total2': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats2:Total_RBV'},
#     'fccd_stats_total3': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats3:Total_RBV'},
#     'fccd_stats_total4': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats4:Total_RBV'},
#     'fccd_stats_total5': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{FCCD}Stats5:Total_RBV'},
#     'gamma': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Gam}Mtr.RBV'},
#     'm1a_pit': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Pit}Mtr_MON'},
#     'm1a_rol': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Rol}Mtr_MON'},
#     'm1a_x': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:X}Mtr_MON'},
#     'm1a_y': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Y}Mtr_MON'},
#     'm1a_yaw': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Yaw}Mtr_MON'},
#     'm1a_z': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23IDA-OP:1{Mir:1-Ax:Z}Mtr_MON'},
#     'm3a_bdr': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mir:3-Ax:Bdr}Mtr.RBV'},
#     'npbx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmX}Mtr.RBV'},
#     'npby': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmY}Mtr.RBV'},
#     'npbz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:BtmZ}Mtr.RBV'},
#     'nptx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopX}Mtr.RBV'},
#     'npty': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopY}Mtr.RBV'},
#     'nptz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif:Lens-Ax:TopZ}Mtr.RBV'},
#     'pgm_energy': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mono}Enrgy-I'},
#     'pgm_energy_sp': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Mono}Enrgy-SP'},
#     'ring_curr': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID-SR{}I-I'},
#     'say': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Y}Mtr.RBV'},
#     'saz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Z}Mtr.RBV'},
#     'sclr_chan1': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S1'},
#     'sclr_chan2': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S2'},
#     'sclr_chan3': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S3'},
#     'sclr_chan4': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S4'},
#     'sclr_chan5': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S5'},
#     'sclr_chan6': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S6'},
#     'sclr_chan7': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S7'},
#     'sclr_chan8': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.S8'},
#     'sclr_time': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Sclr:1}.T'},
#     'slt1_xc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XCtr}Mtr.RBV'},
#     'slt1_xg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:XGap}Mtr.RBV'},
#     'slt1_yc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YCtr}Mtr.RBV'},
#     'slt1_yg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:1-Ax:YGap}Mtr.RBV'},
#     'slt2_xc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XCtr}Mtr.RBV'},
#     'slt2_xg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:XGap}Mtr.RBV'},
#     'slt2_yc': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YCtr}Mtr.RBV'},
#     'slt2_yg': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:2-Ax:YGap}Mtr.RBV'},
#     'slt3_x': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:3-Ax:X}Mtr.RBV'},
#     'slt3_y': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-OP{Slt:3-Ax:Y}Mtr.RBV'},
#     'sx': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#     'sy': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#     'sz': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:SZ}Pos-RB'},
#     'temp_a': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#     'temp_b': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'},
#     'theta': {'dtype': 'number',
#      'shape': [],
#      'source': 'PV:XF:23ID1-ES{Dif-Ax:Th}Mtr.RBV'}},
#    'run_start': {'beamline_id': 'CSX',
#     'config': {},
#     'group': '',
#     'owner': 'xf23id1',
#     'project': 'SAF 300177, Prop. 300369',
#     'sample': {'sample': 'xpcs25_138'},
#     'scan_id': 56428,
#     'scan_type': 'Count',
#     'time': 1447945964.532538,
#     'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#    'time': 1447946092.0155044,
#    'uid': '74e158e0-96fd-4137-b360-ba84b43977f1'},
#   'seq_num': 1,
#   'time': 1447946092.039139,
#   'timestamps': {'delta': 1447922242.109872,
#    'epu1_gap': 1447946091.794043,
#    'epu1_phase': 1447946091.832232,
#    'epu2_gap': 1447946091.925366,
#    'epu2_phase': 1447946090.981466,
#    'eta': 1447686379.47819,
#    'fccd_acquire_period': 1447089296.827231,
#    'fccd_acquire_time': 1447945400.333751,
#    'fccd_image_lightfield': 1447946091.904507,
#    'fccd_stats_total1': 1447946091.903744,
#    'fccd_stats_total2': 1447946091.911404,
#    'fccd_stats_total3': 1447946091.911682,
#    'fccd_stats_total4': 1447946091.911858,
#    'fccd_stats_total5': 1447946091.901194,
#    'gamma': 1447907391.561242,
#    'm1a_pit': 1447919179.662958,
#    'm1a_rol': 1447919179.663057,
#    'm1a_x': 1447919179.663202,
#    'm1a_y': 1447919179.663176,
#    'm1a_yaw': 1447919179.66307,
#    'm1a_z': 1447919179.663187,
#    'm3a_bdr': 1447924222.174169,
#    'npbx': 1447946091.957448,
#    'npby': 1447946089.917354,
#    'npbz': 1447946088.898603,
#    'nptx': 1447946091.948101,
#    'npty': 1447946091.951224,
#    'nptz': 1447946078.651855,
#    'pgm_energy': 1447946091.934182,
#    'pgm_energy_sp': 1447940750.261772,
#    'ring_curr': 1447946091.095016,
#    'say': 1447895037.227402,
#    'saz': 1447895041.824885,
#    'sclr_chan1': 1447945965.120869,
#    'sclr_chan2': 1447945965.120869,
#    'sclr_chan3': 1447945965.120869,
#    'sclr_chan4': 1447945965.120869,
#    'sclr_chan5': 1447945965.120869,
#    'sclr_chan6': 1447867645.13862,
#    'sclr_chan7': 1447867645.13862,
#    'sclr_chan8': 1447867645.13862,
#    'sclr_time': 1447945965.120869,
#    'slt1_xc': 1447946084.6963,
#    'slt1_xg': 1447946088.712624,
#    'slt1_yc': 1447931362.529507,
#    'slt1_yg': 1447946090.430477,
#    'slt2_xc': 1447867645.062325,
#    'slt2_xg': 1447867645.062304,
#    'slt2_yc': 1447867645.821821,
#    'slt2_yg': 1447867645.8218,
#    'slt3_x': 1447946077.553153,
#    'slt3_y': 1447946069.229347,
#    'sx': 1447898364.880222,
#    'sy': 1447895041.824973,
#    'sz': 1447895041.824982,
#    'temp_a': 1447946091.04889,
#    'temp_b': 1447946091.118655,
#    'theta': 1447907318.324657},
#   'uid': 'f9abb12e-02ed-4eef-9e37-357048fc6184'}]

# %%
dd = list(pivot_timeseries(events1, ['fccd_image_lightfield'], ['sx', 'sy', 'temp_a', 'temp_b', 'sy']))

# %%
dd[5]['data']
# Out:
# {'data': {'fccd_image_lightfield': array([[53357, 53357, 53355, ..., 53263, 53264, 53238],
#          [53356, 53355, 53356, ..., 53264, 53265, 53239],
#          [53358, 53357, 53356, ..., 53262, 53262, 53236],
#          ...,
#          [53178, 53181, 53183, ..., 53206, 53208, 53208],
#          [53178, 53183, 53181, ..., 53208, 53207, 53208],
#          [53176, 53183, 53183, ..., 53209, 53210, 53208]], dtype=uint16),
#   'fr_no': 5,
#   'sx': 1.299999535,
#   'sy': -0.39999941231915037,
#   'temp_a': 199.996,
#   'temp_b': 201.303},
#  'descriptor': {'data_keys': {'fccd_image_lightfield': {'dtype': 'array',
#     'shape': [960, 960],
#     'source': 'f9abb12e-02ed-4eef-9e37-357048fc6184'},
#    'fr_no': {'dtype': 'number', 'shape': (), 'source': 'pivot'},
#    'sx': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#    'sy': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#    'temp_a': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#    'temp_b': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'}},
#   'run_start': {'beamline_id': 'CSX',
#    'config': {},
#    'group': '',
#    'owner': 'xf23id1',
#    'project': 'SAF 300177, Prop. 300369',
#    'sample': {'sample': 'xpcs25_138'},
#    'scan_id': 56428,
#    'scan_type': 'Count',
#    'time': 1447945964.532538,
#    'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#   'time': 1447950789.3274205,
#   'uid': 'd51f6680-895d-445c-815d-a34a36fc267e'},
#  'seq_no': 5,
#  'time': 1447946092.039139,
#  'timestamps': {'fccd_image_lightfield': 1447946091.904507,
#   'fr_no': 1447950789.3277075,
#   'sx': 1447898364.880222,
#   'sy': 1447895041.824973,
#   'temp_a': 1447946091.04889,
#   'temp_b': 1447946091.118655},
#  'uid': 'e247dc51-8883-4c43-a95e-dfc690131302'}

# %%
events_fccd5 = list(get_events_generator(h.descriptors[-2]))

# %%
len(dd)
# Out:
# 60

# %%
merged_events = list(zip_events(dd, events_fccd5))

# %%
merged_events[0]
# Out:
# {'data': {'fccd_flyer5': 49060328659.0,
#   'fccd_image_lightfield': array([[53358, 53359, 53357, ..., 53264, 53264, 53239],
#          [53357, 53358, 53355, ..., 53264, 53262, 53237],
#          [53356, 53359, 53356, ..., 53265, 53265, 53239],
#          ...,
#          [53178, 53182, 53184, ..., 53207, 53207, 53208],
#          [53177, 53183, 53183, ..., 53208, 53211, 53208],
#          [53179, 53183, 53185, ..., 53210, 53209, 53210]], dtype=uint16),
#   'fr_no': 0,
#   'sx': 1.299999535,
#   'sy': -0.39999941231915037,
#   'temp_a': 199.996,
#   'temp_b': 201.303},
#  'descriptor': {'data_keys': {'fccd_flyer5': {'dtype': 'number',
#     'shape': [],
#     'source': 'XF:23ID1-ES{FCCD}Stats5:'},
#    'fccd_image_lightfield': {'dtype': 'array',
#     'shape': [960, 960],
#     'source': 'f9abb12e-02ed-4eef-9e37-357048fc6184'},
#    'fr_no': {'dtype': 'number', 'shape': (), 'source': 'pivot'},
#    'sx': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#    'sy': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#    'temp_a': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#    'temp_b': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'}},
#   'run_start': {'beamline_id': 'CSX',
#    'config': {},
#    'group': '',
#    'owner': 'xf23id1',
#    'project': 'SAF 300177, Prop. 300369',
#    'sample': {'sample': 'xpcs25_138'},
#    'scan_id': 56428,
#    'scan_type': 'Count',
#    'time': 1447945964.532538,
#    'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#   'time': 1447951090.823177,
#   'uid': '5d430e61-3286-4822-bb1a-359f8334231b'},
#  'seq_no': 0,
#  'time': 1447951090.823413,
#  'timestamps': {'fccd_flyer5': 1447945973.8791203,
#   'fccd_image_lightfield': 1447946091.904507,
#   'fr_no': 1447950789.327546,
#   'sx': 1447898364.880222,
#   'sy': 1447895041.824973,
#   'temp_a': 1447946091.04889,
#   'temp_b': 1447946091.118655},
#  'uid': '4394a2f5-33a8-4c45-9e95-797099025801'}

# %%
good_event = list(reset_time(merged_events, 'fccd_flyer5'))

# %%
good_event[0]
# Out:
# {'data': {'fccd_flyer5': 49060328659.0,
#   'fccd_image_lightfield': array([[53358, 53359, 53357, ..., 53264, 53264, 53239],
#          [53357, 53358, 53355, ..., 53264, 53262, 53237],
#          [53356, 53359, 53356, ..., 53265, 53265, 53239],
#          ...,
#          [53178, 53182, 53184, ..., 53207, 53207, 53208],
#          [53177, 53183, 53183, ..., 53208, 53211, 53208],
#          [53179, 53183, 53185, ..., 53210, 53209, 53210]], dtype=uint16),
#   'fr_no': 0,
#   'sx': 1.299999535,
#   'sy': -0.39999941231915037,
#   'temp_a': 199.996,
#   'temp_b': 201.303},
#  'descriptor': {'data_keys': {'fccd_flyer5': {'dtype': 'number',
#     'shape': [],
#     'source': 'XF:23ID1-ES{FCCD}Stats5:'},
#    'fccd_image_lightfield': {'dtype': 'array',
#     'shape': [960, 960],
#     'source': 'f9abb12e-02ed-4eef-9e37-357048fc6184'},
#    'fr_no': {'dtype': 'number', 'shape': (), 'source': 'pivot'},
#    'sx': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{Dif-Ax:X}Mtr.RBV'},
#    'sy': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{Dif-Ax:SY}Pos-RB'},
#    'temp_a': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:A}T-I'},
#    'temp_b': {'dtype': 'number',
#     'shape': [],
#     'source': 'PV:XF:23ID1-ES{TCtrl:1-Chan:B}T-I'}},
#   'run_start': {'beamline_id': 'CSX',
#    'config': {},
#    'group': '',
#    'owner': 'xf23id1',
#    'project': 'SAF 300177, Prop. 300369',
#    'sample': {'sample': 'xpcs25_138'},
#    'scan_id': 56428,
#    'scan_type': 'Count',
#    'time': 1447945964.532538,
#    'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#   'time': 1447951090.823177,
#   'uid': '5d430e61-3286-4822-bb1a-359f8334231b'},
#  'seq_no': 0,
#  'time': 1447945973.8791203,
#  'timestamps': {'fccd_flyer5': 1447945973.8791203,
#   'fccd_image_lightfield': 1447946091.904507,
#   'fr_no': 1447950789.327546,
#   'sx': 1447898364.880222,
#   'sy': 1447895041.824973,
#   'temp_a': 1447946091.04889,
#   'temp_b': 1447946091.118655},
#  'uid': '4394a2f5-33a8-4c45-9e95-797099025801'}

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

plt.imshow([e['data']['fccd_image_lightfield'] for e in good_event][25], interpolation='none', cmap='jet')
# Out:
# <img src="data:image/png;base64,...">

# %%
list(get_events_generator(h.descriptors[-3]))
# Out:
# [{'data': {'topoff_inj': 0},
#   'descriptor': {'data_keys': {'topoff_inj': {'dtype': 'number',
#      'shape': [],
#      'source': 'XF:23ID1-SR{TO-Inj}'}},
#    'run_start': {'beamline_id': 'CSX',
#     'config': {},
#     'group': '',
#     'owner': 'xf23id1',
#     'project': 'SAF 300177, Prop. 300369',
#     'sample': {'sample': 'xpcs25_138'},
#     'scan_id': 56428,
#     'scan_type': 'Count',
#     'time': 1447945964.532538,
#     'uid': '95f25412-a093-46bd-ba8b-d23e8e46a5e5'},
#    'time': 1447946092.053964,
#    'uid': 'f24420c1-3244-48e4-b721-dc7a7bb24104'},
#   'seq_num': 1,
#   'time': 1447946003.261154,
#   'timestamps': {'topoff_inj': 1447946003.261154},
#   'uid': '3fdf8842-4e73-4e44-9cbf-c5f7cea400c3'}]
